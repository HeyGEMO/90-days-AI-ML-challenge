# %% [raw]
# import pandas as pd

# %%
df=pd.read_csv('D:/90 days AI Ml/Day 13 project/Sales_Data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pd.read_csv('D:/90 days AI Ml/Day 13 project/Sales_Data.csv')
#
# NameError: name 'pd' is not defined
