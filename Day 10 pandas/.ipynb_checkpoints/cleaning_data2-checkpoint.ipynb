# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:/90 days AI Ml/Day 10 pandas/messy_sales_data.csv')
df
# Out:
#     Order_ID    Customer Name                      email     Phone Number  \
# 0       1001    Alice Johnson    alice.johnson@email.com         555-0101
# 1       1002        BOB SMITH        bob.smith@email.com      +1-555-0102
# 2       1003        Clara Lee        CLARA.LEE@EMAIL.COM  (44) 20-5550103
# 3       1004     david muller     david.muller@email.com   +49-30-5550104
# 4       1005      Emma Nguyen      emma.nguyen@email.com     61-2-5550105
# 5       1006              NaN      frank.rossi@email.com   +39-06-5550106
# 6       1007        Grace Kim        grace.kim@email.com     82-2-5550107
# 7       1008      Hiro Tanaka      hiro.tanaka@email.com    +81-3-5550108
# 8       1009  Isabella Garcia  isabella.garcia@email.com   +34-91-5550109
# 9       1010     James Wilson     james.wilson@email.com       1-555-0110
# 10      1011    Alice Johnson    alice.johnson@email.com         555-0101
# 11      1012      Karen Patel      karen.patel@email.com    91-22-5550111
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       54 non-null     int64
#  1   Customer Name  52 non-null     object
#  2   email          54 non-null     object
#  3   Phone Number   53 non-null     object
#  4   Region         53 non-null     object
#  5   country        53 non-null     object
#  6   Product        54 non-null     object
#  7   Qty            54 non-null     int64
#  8   unit price     53 non-null     float64
#  9   Discount       46 non-null     object
#  10  Total          54 non-null     object
#  11  Order Date     54 non-null     object
#  12  Status         54 non-null     object
#  13  payment        53 non-null     object
#  14  Sales_Rep      53 non-null     object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.5+ KB

# %%
df.describe()
# Out:
#           Order_ID        Qty  unit price
# count    54.000000  54.000000   53.000000
# mean   1027.500000   1.759259  101.963585
# std      15.732133   1.541075  148.594879
# min    1001.000000  -1.000000    3.500000
# 25%    1014.250000   1.000000   34.990000
# 50%    1027.500000   1.000000   55.000000
# 75%    1040.750000   2.000000   89.990000
# max    1054.000000  10.000000  799.990000

# %%
df.describe().round()
# Out:
#        Order_ID   Qty  unit price
# count      54.0  54.0        53.0
# mean     1028.0   2.0       102.0
# std        16.0   2.0       149.0
# min      1001.0  -1.0         4.0
# 25%      1014.0   1.0        35.0
# 50%      1028.0   1.0        55.0
# 75%      1041.0   2.0        90.0
# max      1054.0  10.0       800.0

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer Name    2
# email            0
# Phone Number     1
# Region           1
# country          1
# Product          0
# Qty              0
# unit price       1
# Discount         8
# Total            0
# Order Date       0
# Status           0
# payment          1
# Sales_Rep        1
# dtype: int64

# %%
df.shape
# Out:
# (54, 15)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Order_ID          0.000000
# Customer Name     3.703704
# email             0.000000
# Phone Number      1.851852
# Region            1.851852
# country           1.851852
# Product           0.000000
# Qty               0.000000
# unit price        1.851852
# Discount         14.814815
# Total             0.000000
# Order Date        0.000000
# Status            0.000000
# payment           1.851852
# Sales_Rep         1.851852
# dtype: float64

# %%
df[df.duplicated()].shape
# Out:
# (0, 15)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer Name, email, Phone Number, Region, country, Product, Qty, unit price, Discount, Total, Order Date, Status, payment, Sales_Rep]
# Index: []

# %%
df['Order_ID'].value_counts()
# Out:
# Order_ID
# 1001    1
# 1041    1
# 1030    1
# 1031    1
# 1032    1
# 1033    1
# 1034    1
# 1035    1
# 1036    1
# 1037    1
# 1038    1
# 1039    1
# 1040    1
# 1042    1
# 1002    1
# 1043    1
# 1044    1
# 1045    1
# 1046    1
# 1047    1
# 1048    1
# 1049    1
# 1050    1
# 1051    1
# 1052    1
# 1053    1
# 1029    1
# 1028    1
# 1027    1
# 1026    1
# 1003    1
# 1004    1
# 1005    1
# 1006    1
# 1007    1
# 1008    1
# 1009    1
# 1010    1
# 1011    1
# 1012    1
# 1013    1
# 1014    1
# 1015    1
# 1016    1
# 1017    1
# 1018    1
# 1019    1
# 1020    1
# 1021    1
# 1022    1
# 1023    1
# 1024    1
# 1025    1
# 1054    1
# Name: count, dtype: int64

# %%
df['Order_ID'].value_counts().head(10)
# Out:
# Order_ID
# 1001    1
# 1041    1
# 1030    1
# 1031    1
# 1032    1
# 1033    1
# 1034    1
# 1035    1
# 1036    1
# 1037    1
# Name: count, dtype: int64

# %%
for col in df.columns:
    if df[col].nunique()<20:
        print(df[col].value_counts())
        print('-'*50)
# Out:
# Region
# North America    15
# Europe            9
# Asia Pacific      8
# north america     4
# europe            4
# asia pacific      3
# Latin America     3
# middle east       3
# Asia pacific      2
# latin america     1
# Latin america     1
# Name: count, dtype: int64
# --------------------------------------------------
# Qty
#  1     29
#  2     13
#  3      6
#  4      2
#  5      1
# -1      1
#  10     1
#  0      1
# Name: count, dtype: int64
# --------------------------------------------------
# Discount
# 0       12
# 10%     10
# 5%       8
# 0%       7
# 15%      4
# 20%      2
# none     2
# -        1
# Name: count, dtype: int64
# --------------------------------------------------
# Status
# Delivered     41
# delivered      4
# Shipped        3
# DELIVERED      2
# Processing     2
# shipped        1
# Pending        1
# Name: count, dtype: int64
# --------------------------------------------------
# payment
# Credit Card      23
# Debit Card        7
# ...

# %%
df['unit price'].unique()
# Out:
# array([ 89.99, 149.99,  59.99,  25.  ,  45.  ,  18.99, 199.99,  12.99,
#         79.99,  34.99,  39.99,  29.99,  35.  , 120.  ,  49.99,  24.99,
#        249.99,   3.5 ,  75.  ,  69.99,  85.  ,  44.99,  25.99, 299.99,
#         14.99, 129.99,  55.  , 699.99,  22.99,  19.99, 349.99, 799.99,
#           nan])

# %%
df_price=df[df['unit price'] != 'nan']['unit price']

# %%
price_median=df_price.dropna().median()

# %%
price_median
# Out:
# 55.0

# %%
#df.replace('nan',price_median,inplace=True)
df.fillna(price_median,inplace=True)

# %%
df['unit price'].unique()
# Out:
# array([ 89.99, 149.99,  59.99,  25.  ,  45.  ,  18.99, 199.99,  12.99,
#         79.99,  34.99,  39.99,  29.99,  35.  , 120.  ,  49.99,  24.99,
#        249.99,   3.5 ,  75.  ,  69.99,  85.  ,  44.99,  25.99, 299.99,
#         14.99, 129.99,  55.  , 699.99,  22.99,  19.99, 349.99, 799.99])

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer Name    0
# email            0
# Phone Number     0
# Region           0
# country          0
# Product          0
# Qty              0
# unit price       0
# Discount         0
# Total            0
# Order Date       0
# Status           0
# payment          0
# Sales_Rep        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       54 non-null     int64
#  1   Customer Name  54 non-null     object
#  2   email          54 non-null     object
#  3   Phone Number   54 non-null     object
#  4   Region         54 non-null     object
#  5   country        54 non-null     object
#  6   Product        54 non-null     object
#  7   Qty            54 non-null     int64
#  8   unit price     54 non-null     float64
#  9   Discount       54 non-null     object
#  10  Total          54 non-null     object
#  11  Order Date     54 non-null     object
#  12  Status         54 non-null     object
#  13  payment        54 non-null     object
#  14  Sales_Rep      54 non-null     object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.5+ KB

# %%
df.head(10)
# Out:
#    Order_ID    Customer Name                      email     Phone Number  \
# 0      1001    Alice Johnson    alice.johnson@email.com         555-0101
# 1      1002        BOB SMITH        bob.smith@email.com      +1-555-0102
# 2      1003        Clara Lee        CLARA.LEE@EMAIL.COM  (44) 20-5550103
# 3      1004     david muller     david.muller@email.com   +49-30-5550104
# 4      1005      Emma Nguyen      emma.nguyen@email.com     61-2-5550105
# 5      1006             55.0      frank.rossi@email.com   +39-06-5550106
# 6      1007        Grace Kim        grace.kim@email.com     82-2-5550107
# 7      1008      Hiro Tanaka      hiro.tanaka@email.com    +81-3-5550108
# 8      1009  Isabella Garcia  isabella.garcia@email.com   +34-91-5550109
# 9      1010     James Wilson     james.wilson@email.com       1-555-0110
#
#           Region      country                Product  Qty  unit price  \
# 0  North America          USA    Wireless Headphones    2       89.99
# ...

# %%
df=pd.read_csv('D:/90 days AI Ml/Day 10 pandas/messy_sales_data.csv')

# %%
df
# Out:
#     Order_ID    Customer Name                      email     Phone Number  \
# 0       1001    Alice Johnson    alice.johnson@email.com         555-0101
# 1       1002        BOB SMITH        bob.smith@email.com      +1-555-0102
# 2       1003        Clara Lee        CLARA.LEE@EMAIL.COM  (44) 20-5550103
# 3       1004     david muller     david.muller@email.com   +49-30-5550104
# 4       1005      Emma Nguyen      emma.nguyen@email.com     61-2-5550105
# 5       1006              NaN      frank.rossi@email.com   +39-06-5550106
# 6       1007        Grace Kim        grace.kim@email.com     82-2-5550107
# 7       1008      Hiro Tanaka      hiro.tanaka@email.com    +81-3-5550108
# 8       1009  Isabella Garcia  isabella.garcia@email.com   +34-91-5550109
# 9       1010     James Wilson     james.wilson@email.com       1-555-0110
# 10      1011    Alice Johnson    alice.johnson@email.com         555-0101
# 11      1012      Karen Patel      karen.patel@email.com    91-22-5550111
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       54 non-null     int64
#  1   Customer Name  52 non-null     object
#  2   email          54 non-null     object
#  3   Phone Number   53 non-null     object
#  4   Region         53 non-null     object
#  5   country        53 non-null     object
#  6   Product        54 non-null     object
#  7   Qty            54 non-null     int64
#  8   unit price     53 non-null     float64
#  9   Discount       46 non-null     object
#  10  Total          54 non-null     object
#  11  Order Date     54 non-null     object
#  12  Status         54 non-null     object
#  13  payment        53 non-null     object
#  14  Sales_Rep      53 non-null     object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.5+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer Name    2
# email            0
# Phone Number     1
# Region           1
# country          1
# Product          0
# Qty              0
# unit price       1
# Discount         8
# Total            0
# Order Date       0
# Status           0
# payment          1
# Sales_Rep        1
# dtype: int64

# %%
df['unit price'].unique()
# Out:
# array([ 89.99, 149.99,  59.99,  25.  ,  45.  ,  18.99, 199.99,  12.99,
#         79.99,  34.99,  39.99,  29.99,  35.  , 120.  ,  49.99,  24.99,
#        249.99,   3.5 ,  75.  ,  69.99,  85.  ,  44.99,  25.99, 299.99,
#         14.99, 129.99,  55.  , 699.99,  22.99,  19.99, 349.99, 799.99,
#           nan])

# %%
df['unit price'].fillna(df['unit price'].median(),inplace=True)
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_8476\1578944718.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['unit price'].fillna(df['unit price'].median(),inplace=True)
