# %%
import pandas as np
import seaborn as sns

# %%
df=sns.load_dataset('sales_data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=sns.load_dataset('sales_data.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'sales_data.csv' is not one of the example datasets.
